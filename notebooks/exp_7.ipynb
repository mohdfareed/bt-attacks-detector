# %% [markdown]
# # Bluetooth DoS Classifier

# %% [markdown]
# This experiment attempted to improve the performance of the Random Forest classifier through hyperparameter tuning. This model was chosen due to its accuracy vs training time. optimization was not done on the Gradient Boosting Classifier due to its very high performance and long training time.
#
# **Findings:**
#
# - Optimization time was 4.5 hours
# - Accuracy did not change after hyperparameter tuning
# - The best parameters were the default ones

# %% [markdown]
# ## Setup

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scienceplots
import seaborn as sns
import sklearn.metrics as metrics
from joblib import dump, load
from scipy.sparse import csr_matrix, hstack, load_npz, save_npz
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from skopt.space import Real, Categorical, Integer
from skopt import BayesSearchCV
from wordcloud import WordCloud

# %%
DATA = os.path.abspath("../data")
MODELS = os.path.abspath("../models")

# data paths
ATTACK_TRAIN = os.path.join(DATA, "dos_train.csv")
BENIGN_TRAIN = os.path.join(DATA, "benign_train.csv")
ATTACK_TEST = os.path.join(DATA, "dos_test.csv")
BENIGN_TEST = os.path.join(DATA, "benign_test.csv")
CAPTURED_DATA = os.path.join(DATA, "capture.csv")

# preprocessed data paths
PREPROCESSED_TRAIN = os.path.join(DATA, "preprocessed_train.csv")
PREPROCESSED_TEST = os.path.join(DATA, "preprocessed_test.csv")
LABELS_TRAIN = os.path.join(DATA, f"labels_train.npy")
LABELS_TEST = os.path.join(DATA, f"labels_test.npy")

# features paths
FEATURES_TEST = os.path.join(DATA, f"features_test.npz")
FEATURES_TRAIN = os.path.join(DATA, f"features_train.npz")

# models paths
VECTORIZER_MODEL = os.path.join(MODELS, f"vectorizer.joblib")
ENCODER_MODEL = os.path.join(MODELS, f"encoder.joblib")
SCALER_MODEL = os.path.join(MODELS, f"scaler.joblib")
HASHER_MODEL = os.path.join(MODELS, "hasher.joblib")
GBM_MODEL = os.path.join(MODELS, f"gbm.joblib")  # gradient boosting machine
RAND_FOREST_MODEL = os.path.join(MODELS, "rand_forest.joblib")  # random forest

# %%
print("Data directory:", DATA)
print("Models directory:", MODELS)

# check that data files exist
data_paths = [ATTACK_TRAIN, BENIGN_TRAIN, ATTACK_TEST, BENIGN_TEST]
if not all(map(os.path.exists, data_paths)):
    raise Exception("Data files not found")

# create directories if they don't exist
if not os.path.exists(MODELS):
    os.makedirs("models")

# format plots
plt.style.use(["science", "ieee"])
# Out:
# Data directory: /Users/mohdfareed/Developer/school/bluetooth-dos-classifier/data
# Models directory: /Users/mohdfareed/Developer/school/bluetooth-dos-classifier/models

# %% [markdown]
# ## Dataset Preprocessing

# %%
# read datasets
attack_train = pd.read_csv(ATTACK_TRAIN)
benign_train = pd.read_csv(BENIGN_TRAIN)
attack_test = pd.read_csv(ATTACK_TEST)
benign_test = pd.read_csv(BENIGN_TEST)
capture = pd.read_csv(CAPTURED_DATA)

# %%
# split captured data (80/20 split) and append to benign data
split_index = int(len(capture) * 0.8)  # required to preserve order
capture_train = capture.iloc[:split_index]
capture_test = capture.iloc[split_index:]
benign_train = pd.concat([benign_train, capture_train], ignore_index=True)
benign_test = pd.concat([benign_test, capture_test], ignore_index=True)

# add type column indicating attack or benign
attack_train["Type"] = 1
attack_test["Type"] = 1
benign_train["Type"] = 0
benign_test["Type"] = 0

# combine datasets
train_dataset = pd.concat([attack_train, benign_train], ignore_index=True)
test_dataset = pd.concat([attack_test, benign_test], ignore_index=True)

# generate labels
train_labels = train_dataset["Type"]
train_dataset.drop(columns=["Type"], inplace=True)
test_labels = test_dataset["Type"]
test_dataset.drop(columns=["Type"], inplace=True)

# %%
# write preprocessed dataset to files
train_dataset.to_csv(PREPROCESSED_TRAIN, index=False)
test_dataset.to_csv(PREPROCESSED_TEST, index=False)
np.save(LABELS_TRAIN, train_labels)
np.save(LABELS_TEST, test_labels)

# %%
# training and testing with labels
plot_training = train_dataset.copy()
plot_training["Type"] = train_labels
plot_testing = test_dataset.copy()
plot_testing["Type"] = test_labels
dataset = pd.concat([plot_training, plot_testing], ignore_index=True)
# summary statistics
print(f"Training and Testing dataset statistics:\n{dataset.describe()}\n")

# histogram of length
plt.figure()
sns.histplot(
    data=dataset,
    x="Length",
    hue="Type",
    element="step",
    stat="density",
    common_norm=False,
)
plt.title("Distribution of Length by Type")
plt.xlabel("Packet Length")
plt.ylabel("Density")
plt.show()

# bar chart for protocol usage
plt.figure()
sns.countplot(x="Protocol", hue="Type", data=dataset)
plt.title("Protocol Usage by Type")
plt.xlabel("Protocol")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# word cloud for info column
wordcloud = WordCloud(
    width=800, height=400, background_color="white"
).generate(" ".join(dataset["Info"]))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Info Column")
plt.show()

# bar chart for source usage
dataset["Source"] = dataset["Source"].apply(
    lambda x: x if len(x) <= 15 else x[:15] + "..."
)
plt.figure()
sns.countplot(
    x="Source",
    hue="Type",
    data=dataset,
    order=dataset["Source"].value_counts().index,
)
plt.title("Frequency of Packets by Source")
plt.xlabel("Source")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# bar chart for destination usage
dataset["Destination"] = dataset["Destination"].apply(
    lambda x: x if len(x) <= 15 else x[:15] + "..."
)
plt.figure()
sns.countplot(
    x="Destination",
    hue="Type",
    data=dataset,
    order=dataset["Destination"].value_counts().index,
)
plt.title("Frequency of Packets by Destination")
plt.xlabel("Destination")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# correlation matrix
plt.figure()
sns.heatmap(
    dataset.select_dtypes(["number"]).corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
)
plt.title("Correlation Matrix")
plt.show()
# Out:
# Training and Testing dataset statistics:
#                 No.          Time        Length          Type
# count  2.533706e+06  2.533706e+06  2.533706e+06  2.533706e+06
# mean   4.170342e+05  1.993675e+05  6.519739e+01  4.933876e-01
# std    3.039178e+05  3.693308e+05  1.507927e+02  4.999564e-01
# min    1.000000e+00  0.000000e+00  3.000000e+00  0.000000e+00
# 25%    1.420250e+05  1.257302e+03  8.000000e+00  0.000000e+00
# 50%    3.661615e+05  3.491526e+03  1.900000e+01  0.000000e+00
# 75%    6.828748e+05  9.224927e+04  3.200000e+01  1.000000e+00
# max    1.000784e+06  1.198804e+06  1.021000e+03  1.000000e+00

# %% [markdown]
# ## Feature Extraction

# %%
# load preprocessed datasets
train_dataset = pd.read_csv(PREPROCESSED_TRAIN)
test_dataset = pd.read_csv(PREPROCESSED_TEST)

# %%
# apply tf-idf vectorization to Info column
vectorizer = TfidfVectorizer(max_features=1000)
train_info = vectorizer.fit_transform(train_dataset["Info"])
test_info = vectorizer.transform(test_dataset["Info"])

# combine features
train_features = hstack([train_info])
test_features = hstack([test_info])

# %%
# write features and models to files
save_npz(FEATURES_TRAIN, train_features)
save_npz(FEATURES_TEST, test_features)
_ = dump(vectorizer, VECTORIZER_MODEL)

# %%
# report feature extraction results
print(f"TF-IDF Vocabulary size: {len(vectorizer.vocabulary_)}")
print(f"Total number of features: {train_features.shape[1]}")

# word cloud of the info column
features = vectorizer.get_feature_names_out()
scores = np.ravel(train_info.sum(axis=0))
word_scores = dict(zip(features, scores))
wordcloud = WordCloud(
    width=800, height=400, background_color="white"
).generate_from_frequencies(word_scores)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud from TF-IDF of Info Column")
plt.show()
# Out:
# TF-IDF Vocabulary size: 1000
# Total number of features: 1000

# %% [markdown]
# ## Model Training

# %%
# load features and labels
train_features = load_npz(FEATURES_TRAIN)
train_labels = np.load(LABELS_TRAIN)

# %%
# report hardware information
print("Hardware information:")
print(f"\tPlatform: {os.uname().sysname}")
print(f"\tProcessor: {os.uname().machine}")
print(f"\tNumber of CPU cores: {os.cpu_count()}")
mem = os.sysconf("SC_PAGE_SIZE") * os.sysconf("SC_PHYS_PAGES") / 1024**3
print(f"\tMemory available: {mem:.2f} GB\n")

# train model
model = RandomForestClassifier(n_jobs=-1, verbose=1)

# define optimization search space
search_spaces = {
    "n_estimators": Integer(100, 500),
    "max_depth": Integer(5, 50),
    "min_samples_split": Integer(2, 20),
    "min_samples_leaf": Integer(1, 10),
}

# perform bayesian optimization
bayes_search = BayesSearchCV(
    estimator=model, search_spaces=search_spaces, n_jobs=-1
)
bayes_search.fit(train_features, train_labels)
model: RandomForestClassifier = bayes_search.best_estimator_
# Out:
# Hardware information:
# 	Platform: Darwin
# 	Processor: arm64
# 	Number of CPU cores: 8
# 	Memory available: 8.00 GB
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   40.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   42.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   43.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   46.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 372 out of 372 | elapsed:  7.2min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 372 out of 372 | elapsed:  7.2min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 372 out of 372 | elapsed:    5.4s finished
# [Parallel(n_jobs=-1)]: Done 372 out of 372 | elapsed:  7.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 372 out of 372 | elapsed:    4.7s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 372 out of 372 | elapsed:    2.7s finished
# [Parallel(n_jobs=-1)]: Done 372 out of 372 | elapsed:  7.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 372 out of 372 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Done 372 out of 372 | elapsed:  7.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 372 out of 372 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   44.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   44.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   46.6s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   54.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 389 out of 389 | elapsed:  8.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 389 out of 389 | elapsed:  8.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=8)]: Done 389 out of 389 | elapsed:    7.5s finished
# [Parallel(n_jobs=8)]: Done 389 out of 389 | elapsed:    7.2s finished
# [Parallel(n_jobs=-1)]: Done 389 out of 389 | elapsed:  8.8min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 389 out of 389 | elapsed:  8.9min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 389 out of 389 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 389 out of 389 | elapsed:    2.1s finished
# [Parallel(n_jobs=-1)]: Done 389 out of 389 | elapsed:  9.0min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 389 out of 389 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.6s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   37.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 482 out of 482 | elapsed:  7.6min finished
# [Parallel(n_jobs=-1)]: Done 482 out of 482 | elapsed:  7.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done 482 out of 482 | elapsed:  7.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=8)]: Done 482 out of 482 | elapsed:    6.4s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 482 out of 482 | elapsed:    6.6s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=8)]: Done 482 out of 482 | elapsed:    4.6s finished
# [Parallel(n_jobs=-1)]: Done 482 out of 482 | elapsed:  7.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 482 out of 482 | elapsed:    2.0s finished
# [Parallel(n_jobs=-1)]: Done 482 out of 482 | elapsed:  7.9min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 482 out of 482 | elapsed:    1.1s finished
# /Users/mohdfareed/Developer/school/bluetooth-dos-classifier/.venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   37.6s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   37.7s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   43.7s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 414 out of 414 | elapsed:  7.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 414 out of 414 | elapsed:  7.6min finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=8)]: Done 414 out of 414 | elapsed:    9.7s finished
# [Parallel(n_jobs=8)]: Done 414 out of 414 | elapsed:    9.1s finished
# [Parallel(n_jobs=-1)]: Done 414 out of 414 | elapsed:  7.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 414 out of 414 | elapsed:    3.9s finished
# [Parallel(n_jobs=-1)]: Done 414 out of 414 | elapsed:  7.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 414 out of 414 | elapsed:    2.1s finished
# [Parallel(n_jobs=-1)]: Done 414 out of 414 | elapsed:  7.9min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 414 out of 414 | elapsed:    1.2s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   49.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   50.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   56.0s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   56.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 296 out of 296 | elapsed:  6.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 296 out of 296 | elapsed:  6.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 296 out of 296 | elapsed:    4.9s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 296 out of 296 | elapsed:  6.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 296 out of 296 | elapsed:    5.1s finished
# [Parallel(n_jobs=8)]: Done 296 out of 296 | elapsed:    4.8s finished
# [Parallel(n_jobs=-1)]: Done 296 out of 296 | elapsed:  6.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 296 out of 296 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Done 296 out of 296 | elapsed:  6.8min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 296 out of 296 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   40.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.7s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   43.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   44.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 489 out of 489 | elapsed:  9.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done 489 out of 489 | elapsed:  9.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=8)]: Done 489 out of 489 | elapsed:   10.0s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=8)]: Done 489 out of 489 | elapsed:    6.8s finished
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 489 out of 489 | elapsed:  9.8min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 489 out of 489 | elapsed:  9.8min finished
# [Parallel(n_jobs=8)]: Done 489 out of 489 | elapsed:    4.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 489 out of 489 | elapsed:    2.6s finished
# [Parallel(n_jobs=-1)]: Done 489 out of 489 | elapsed:  9.9min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 489 out of 489 | elapsed:    1.5s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   37.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   43.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   43.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   44.6s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   48.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 309 out of 309 | elapsed:  5.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 309 out of 309 | elapsed:  5.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 309 out of 309 | elapsed:    6.9s finished
# [Parallel(n_jobs=8)]: Done 309 out of 309 | elapsed:    5.1s finished
# [Parallel(n_jobs=-1)]: Done 309 out of 309 | elapsed:  5.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 309 out of 309 | elapsed:    2.8s finished
# [Parallel(n_jobs=-1)]: Done 309 out of 309 | elapsed:  5.8min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 309 out of 309 | elapsed:    2.7s finished
# [Parallel(n_jobs=-1)]: Done 309 out of 309 | elapsed:  5.9min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 309 out of 309 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   45.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   46.6s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   49.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   50.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   56.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 404 out of 404 | elapsed:  6.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 404 out of 404 | elapsed:  6.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 404 out of 404 | elapsed:    5.8s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 404 out of 404 | elapsed:    4.7s finished
# [Parallel(n_jobs=-1)]: Done 404 out of 404 | elapsed:  6.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 404 out of 404 | elapsed:    2.8s finished
# [Parallel(n_jobs=-1)]: Done 404 out of 404 | elapsed:  6.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 404 out of 404 | elapsed:    2.1s finished
# [Parallel(n_jobs=-1)]: Done 404 out of 404 | elapsed:  6.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 404 out of 404 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   33.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   35.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   36.0s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   39.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 468 out of 468 | elapsed:  7.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 468 out of 468 | elapsed:  7.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=8)]: Done 468 out of 468 | elapsed:    7.6s finished
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=8)]: Done 468 out of 468 | elapsed:    7.8s finished
# [Parallel(n_jobs=-1)]: Done 468 out of 468 | elapsed:  7.9min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 468 out of 468 | elapsed:  8.0min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 468 out of 468 | elapsed:    3.7s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=8)]: Done 468 out of 468 | elapsed:    2.9s finished
# [Parallel(n_jobs=-1)]: Done 468 out of 468 | elapsed:  8.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 468 out of 468 | elapsed:    1.3s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   37.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 347 out of 347 | elapsed:  4.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 347 out of 347 | elapsed:  4.8min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 347 out of 347 | elapsed:    4.2s finished
# [Parallel(n_jobs=-1)]: Done 347 out of 347 | elapsed:  4.8min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 347 out of 347 | elapsed:    3.4s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 347 out of 347 | elapsed:    2.1s finished
# [Parallel(n_jobs=-1)]: Done 347 out of 347 | elapsed:  4.9min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 347 out of 347 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Done 347 out of 347 | elapsed:  4.9min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 347 out of 347 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:  5.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:  5.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:  5.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.0s finished
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    7.2s finished
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:  5.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.0s finished
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.2s finished
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:  5.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   46.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   46.8s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   49.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=-1)]: Done 137 out of 137 | elapsed:  2.8min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 137 out of 137 | elapsed:  2.9min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 137 out of 137 | elapsed:  2.9min finished
# [Parallel(n_jobs=8)]: Done 137 out of 137 | elapsed:    1.3s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 137 out of 137 | elapsed:    1.9s finished
# [Parallel(n_jobs=8)]: Done 137 out of 137 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Done 137 out of 137 | elapsed:  2.9min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 137 out of 137 | elapsed:  2.9min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 137 out of 137 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 137 out of 137 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   23.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 292 out of 292 | elapsed:  3.3min finished
# [Parallel(n_jobs=-1)]: Done 292 out of 292 | elapsed:  3.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 292 out of 292 | elapsed:  3.3min finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 292 out of 292 | elapsed:    3.1s finished
# [Parallel(n_jobs=8)]: Done 292 out of 292 | elapsed:    3.4s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 292 out of 292 | elapsed:  3.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 292 out of 292 | elapsed:    2.5s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 292 out of 292 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Done 292 out of 292 | elapsed:  3.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 292 out of 292 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   59.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 117 out of 117 | elapsed:  3.1min finished
# [Parallel(n_jobs=-1)]: Done 117 out of 117 | elapsed:  3.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 117 out of 117 | elapsed:    1.6s finished
# [Parallel(n_jobs=8)]: Done 117 out of 117 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Done 117 out of 117 | elapsed:  3.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 117 out of 117 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Done 117 out of 117 | elapsed:  3.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 117 out of 117 | elapsed:  3.2min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 117 out of 117 | elapsed:    0.4s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 117 out of 117 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   45.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   45.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   47.6s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   48.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   55.3s
# [Parallel(n_jobs=-1)]: Done 187 out of 187 | elapsed:  3.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 187 out of 187 | elapsed:  3.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 187 out of 187 | elapsed:    6.6s finished
# [Parallel(n_jobs=8)]: Done 187 out of 187 | elapsed:    5.7s finished
# [Parallel(n_jobs=-1)]: Done 187 out of 187 | elapsed:  3.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 187 out of 187 | elapsed:  3.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 187 out of 187 | elapsed:    1.5s finished
# [Parallel(n_jobs=8)]: Done 187 out of 187 | elapsed:    1.2s finished
# [Parallel(n_jobs=-1)]: Done 187 out of 187 | elapsed:  3.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 187 out of 187 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 144 out of 144 | elapsed:  4.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 144 out of 144 | elapsed:  4.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 144 out of 144 | elapsed:    2.9s finished
# [Parallel(n_jobs=8)]: Done 144 out of 144 | elapsed:    2.6s finished
# [Parallel(n_jobs=-1)]: Done 144 out of 144 | elapsed:  4.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 144 out of 144 | elapsed:  4.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 144 out of 144 | elapsed:    2.0s finished
# [Parallel(n_jobs=8)]: Done 144 out of 144 | elapsed:    2.4s finished
# [Parallel(n_jobs=-1)]: Done 144 out of 144 | elapsed:  4.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 144 out of 144 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   37.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   38.7s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   38.0s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   39.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 306 out of 306 | elapsed:  4.2min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 306 out of 306 | elapsed:  4.2min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 306 out of 306 | elapsed:  4.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 306 out of 306 | elapsed:    8.5s finished
# [Parallel(n_jobs=8)]: Done 306 out of 306 | elapsed:    6.7s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 306 out of 306 | elapsed:  4.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 306 out of 306 | elapsed:    3.9s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 306 out of 306 | elapsed:    1.5s finished
# [Parallel(n_jobs=-1)]: Done 306 out of 306 | elapsed:  4.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 306 out of 306 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 119 out of 119 | elapsed:  4.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 119 out of 119 | elapsed:  4.2min finished
# ...
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 298 out of 298 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Done 298 out of 298 | elapsed:  5.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 298 out of 298 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.8s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   42.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   43.8s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   47.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 420 out of 420 | elapsed:  8.2min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 420 out of 420 | elapsed:  8.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 420 out of 420 | elapsed:    8.4s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 420 out of 420 | elapsed:  8.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 420 out of 420 | elapsed:    5.7s finished
# [Parallel(n_jobs=8)]: Done 420 out of 420 | elapsed:    4.6s finished
# [Parallel(n_jobs=-1)]: Done 420 out of 420 | elapsed:  8.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 420 out of 420 | elapsed:    2.5s finished
# [Parallel(n_jobs=-1)]: Done 420 out of 420 | elapsed:  8.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 420 out of 420 | elapsed:    1.3s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   39.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   40.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   48.0s
# [Parallel(n_jobs=-1)]: Done 142 out of 142 | elapsed:  2.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 142 out of 142 | elapsed:  2.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 142 out of 142 | elapsed:    2.5s finished
# [Parallel(n_jobs=8)]: Done 142 out of 142 | elapsed:    2.3s finished
# [Parallel(n_jobs=-1)]: Done 142 out of 142 | elapsed:  2.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 142 out of 142 | elapsed:    1.3s finished
# [Parallel(n_jobs=-1)]: Done 142 out of 142 | elapsed:  2.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 142 out of 142 | elapsed:  2.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 142 out of 142 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Done 142 out of 142 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   44.7s
# [Parallel(n_jobs=-1)]: Done 130 out of 130 | elapsed:  2.0min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 130 out of 130 | elapsed:  2.0min finished
# [Parallel(n_jobs=8)]: Done 130 out of 130 | elapsed:    1.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 130 out of 130 | elapsed:  2.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 130 out of 130 | elapsed:    1.0s finished
# [Parallel(n_jobs=8)]: Done 130 out of 130 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Done 130 out of 130 | elapsed:  2.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 130 out of 130 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Done 130 out of 130 | elapsed:  2.0min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 130 out of 130 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   43.0s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   49.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   49.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   52.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 265 out of 265 | elapsed:  5.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 265 out of 265 | elapsed:    5.8s finished
# [Parallel(n_jobs=-1)]: Done 265 out of 265 | elapsed:  5.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 265 out of 265 | elapsed:  5.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 265 out of 265 | elapsed:    3.0s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 265 out of 265 | elapsed:    2.9s finished
# [Parallel(n_jobs=-1)]: Done 265 out of 265 | elapsed:  5.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 265 out of 265 | elapsed:    1.6s finished
# [Parallel(n_jobs=-1)]: Done 265 out of 265 | elapsed:  5.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 265 out of 265 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   27.6s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   28.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 498 out of 498 | elapsed:  6.2min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 498 out of 498 | elapsed:  6.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=8)]: Done 498 out of 498 | elapsed:    8.2s finished
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 498 out of 498 | elapsed:    7.9s finished
# [Parallel(n_jobs=-1)]: Done 498 out of 498 | elapsed:  6.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 498 out of 498 | elapsed:  6.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 498 out of 498 | elapsed:    3.0s finished
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 498 out of 498 | elapsed:    2.6s finished
# [Parallel(n_jobs=-1)]: Done 498 out of 498 | elapsed:  6.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 498 out of 498 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   39.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   45.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   46.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=-1)]: Done 130 out of 130 | elapsed:  2.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 130 out of 130 | elapsed:    2.0s finished
# [Parallel(n_jobs=-1)]: Done 130 out of 130 | elapsed:  2.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 130 out of 130 | elapsed:  2.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 130 out of 130 | elapsed:  2.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 130 out of 130 | elapsed:    1.3s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 130 out of 130 | elapsed:    1.3s finished
# [Parallel(n_jobs=8)]: Done 130 out of 130 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Done 130 out of 130 | elapsed:  2.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 130 out of 130 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    7.0s finished

# %%
# write model to file
_ = dump(model, RAND_FOREST_MODEL)

# %% [markdown]
# ## Evaluation

# %%
# load model and features
model = load(RAND_FOREST_MODEL)
vectorizer = load(VECTORIZER_MODEL)
test_features = load_npz(FEATURES_TEST)
test_labels = np.load(LABELS_TEST)
model.verbose = 0

# %%
# report best parameters
best_parameters = model.get_params()
print("Parameters of the Best Estimator:")
for param, value in best_parameters.items():
    print(f"{param}: {value}")

# predictions
predictions = model.predict(test_features)
predictions_prob = model.predict_proba(test_features)[:, 1]

# evaluate model
accuracy = metrics.accuracy_score(test_labels, predictions)
print(f"Train accuracy: {accuracy}\n")
conf_matrix = metrics.confusion_matrix(test_labels, predictions)
print(f"Confusion matrix:\n{conf_matrix}\n")
report = metrics.classification_report(test_labels, predictions)
print(f"Classification report:\n{report}")

# compute precision-recall curve and area
precision, recall, _ = metrics.precision_recall_curve(
    test_labels, predictions_prob
)
pr_auc = metrics.auc(recall, precision)
# plot precision-recall curve
plt.figure()
plt.plot(recall, precision, label=f"PR Curve (area = {pr_auc:.2f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend(loc="best")
plt.show()

# compute roc curve and area
fpr, tpr, _ = metrics.roc_curve(test_labels, predictions_prob)
roc_auc = metrics.auc(fpr, tpr)
# plot roc curve
plt.figure()
plt.plot(fpr, tpr, label=f"ROC Curve (area = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], color="navy", linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic")
plt.legend(loc="lower right")
plt.show()

# prepare feature names
tfidf_features = [
    "info_" + feature for feature in vectorizer.get_feature_names_out()
]
# combine all feature names
all_feature_names = list(tfidf_features)

# prepare feature importances
importances = model.feature_importances_
feature_importance_df = pd.DataFrame(
    {"Feature": all_feature_names, "Importance": importances}
)
sorted_feature_importance = feature_importance_df.sort_values(
    by="Importance", ascending=False
)

# plot feature importance
top_features = sorted_feature_importance.head(40)  # top n features
plt.figure(figsize=(6.4, 6))
sns.barplot(x="Importance", y="Feature", data=top_features)
plt.title("Top Feature Importances")
plt.show()
# Out:
# Parameters of the Best Estimator:
# bootstrap: True
# ccp_alpha: 0.0
# class_weight: None
# criterion: gini
# max_depth: 5
# max_features: sqrt
# max_leaf_nodes: None
# max_samples: None
# min_impurity_decrease: 0.0
# min_samples_leaf: 10
# min_samples_split: 20
# min_weight_fraction_leaf: 0.0
# monotonic_cst: None
# n_estimators: 100
# n_jobs: -1
# oob_score: False
# random_state: None
# verbose: 0
# warm_start: False
# Train accuracy: 0.9146801496534189
#
# Confusion matrix:
# [[221806  43681]
#  [   446 251262]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91    265487
#            1       0.85      1.00      0.92    251708
#
#     accuracy                           0.91    517195
#    macro avg       0.92      0.92      0.91    517195
# weighted avg       0.93      0.91      0.91    517195
